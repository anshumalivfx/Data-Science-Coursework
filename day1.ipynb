# %%
# %config IPCompleter.greedy=True
import pandas as pd

# %%
death_data = pd.read_csv("DATA/deaths.csv")

# %%
x = death_data["time"]
a = x[0:15]
print(x)
# Out:
# 0     1974.000000
# 1     1974.083333
# 2     1974.166667
# 3     1974.250000
# 4     1974.333333
#          ...
# 67    1979.583333
# 68    1979.666667
# 69    1979.750000
# 70    1979.833333
# 71    1979.916667
# Name: time, Length: 72, dtype: float64

# %%
x = death_data.iloc[:15, 1]
print(x)
# Out:
# 0     1974.000000
# 1     1974.083333
# 2     1974.166667
# 3     1974.250000
# 4     1974.333333
# 5     1974.416667
# 6     1974.500000
# 7     1974.583333
# 8     1974.666667
# 9     1974.750000
# 10    1974.833333
# 11    1974.916667
# 12    1975.000000
# 13    1975.083333
# 14    1975.166667
# Name: time, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
x = death_data.iloc[:15, 1]
y = death_data.iloc[:15, 2]

plt.style.use("dark_background")
plt.figure()
plt.scatter(x,y)
plt.plot(x,y)
plt.show()
